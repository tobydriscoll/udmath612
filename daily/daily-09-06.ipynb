# %%
using LinearAlgebra

# %%
using DelimitedFiles, PyPlot
A = readdlm("hou111kh_matrix.txt");
imshow(A); colorbar(orientation="horizontal");
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
A = rand(6,4)
# Out:
# 6×4 Array{Float64,2}:
#  0.622135  0.151022  0.428404  0.930054
#  0.789573  0.122676  0.856904  0.895849
#  0.881966  0.905603  0.929246  0.623882
#  0.370133  0.449387  0.389829  0.678575
#  0.660562  0.427967  0.670375  0.583767
#  0.837739  0.416476  0.790509  0.608003

# %%
U,σ,V = svd(A)
# Out:
# SVD{Float64,Float64,Array{Float64,2}}([-0.356334 -0.567423 0.367845 0.573508; -0.449576 -0.470661 -0.437639 -0.566922; … ; -0.373391 0.10574 -0.0809064 -0.016283; -0.427522 0.0992562 -0.382855 0.406635], [3.17259, 0.691766, 0.39436, 0.126248], [-0.549075 -0.328671 -0.541105 -0.545617; 0.00368054 0.768055 0.156002 -0.62108; -0.357423 0.549334 -0.521707 0.546171; 0.755481 0.0172776 -0.640851 -0.135125])

# %%
U
# Out:
# 6×4 Array{Float64,2}:
#  -0.356334  -0.567423    0.367845    0.573508
#  -0.449576  -0.470661   -0.437639   -0.566922
#  -0.512242   0.659591    0.0968555   0.0169868
#  -0.293802  -0.0204105   0.714603   -0.428699
#  -0.373391   0.10574    -0.0809064  -0.016283
#  -0.427522   0.0992562  -0.382855    0.406635

# %%
V
# Out:
# 4×4 Adjoint{Float64,Array{Float64,2}}:
#  -0.549075   0.00368054  -0.357423   0.755481
#  -0.328671   0.768055     0.549334   0.0172776
#  -0.541105   0.156002    -0.521707  -0.640851
#  -0.545617  -0.62108      0.546171  -0.135125

# %%
σ
# Out:
# 4-element Array{Float64,1}:
#  3.1725854668651765
#  0.6917658990917483
#  0.3943598034663508
#  0.12624776799902065

# %%
U,σ,V = svd(A,full=true)
# Out:
# SVD{Float64,Float64,Array{Float64,2}}([-0.356334 -0.567423 … -0.0852119 -0.282091; -0.449576 -0.470661 … -0.204632 -0.146822; … ; -0.373391 0.10574 … 0.905078 -0.153036; -0.427522 0.0992562 … -0.0969985 0.697162], [3.17259, 0.691766, 0.39436, 0.126248], [-0.549075 -0.328671 -0.541105 -0.545617; 0.00368054 0.768055 0.156002 -0.62108; -0.357423 0.549334 -0.521707 0.546171; 0.755481 0.0172776 -0.640851 -0.135125])

# %%
U
# Out:
# 6×6 Array{Float64,2}:
#  -0.356334  -0.567423    0.367845    0.573508   -0.0852119  -0.282091
#  -0.449576  -0.470661   -0.437639   -0.566922   -0.204632   -0.146822
#  -0.512242   0.659591    0.0968555   0.0169868  -0.349314   -0.41335
#  -0.293802  -0.0204105   0.714603   -0.428699    0.0163908   0.467498
#  -0.373391   0.10574    -0.0809064  -0.016283    0.905078   -0.153036
#  -0.427522   0.0992562  -0.382855    0.406635   -0.0969985   0.697162

# %%
U'*U - I
# Out:
# 6×6 Array{Float64,2}:
#   0.0           1.10798e-17   2.14634e-17  …  -3.25204e-18  -1.99533e-17
#   1.10798e-17  -5.55112e-16   2.69524e-16      8.69314e-17   8.95161e-17
#   2.14634e-17   2.69524e-16  -7.77156e-16     -2.64697e-17  -4.41637e-17
#  -6.37077e-18   1.0115e-16    2.28197e-16     -4.49953e-17  -1.06162e-16
#  -3.25204e-18   8.69314e-17  -2.64697e-17      0.0           2.1187e-17
#  -1.99533e-17   8.95161e-17  -4.41637e-17  …   2.1187e-17    2.22045e-16

# %%
Σ = Diagonal(σ)
# Out:
# 4×4 Diagonal{Float64,Array{Float64,1}}:
#  3.17259   ⋅         ⋅        ⋅
#   ⋅       0.691766   ⋅        ⋅
#   ⋅        ⋅        0.39436   ⋅
#   ⋅        ⋅         ⋅       0.126248

# %%
svdvals(A)  # only the singular values
# Out:
# 4-element Array{Float64,1}:
#  3.1725854668651756
#  0.6917658990917482
#  0.39435980346635063
#  0.12624776799902068
